# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import cPickle as cp
import sys
sys.path.append("../../utils")

from plot_utils import get_colors

# %%
colors_dict = get_colors()

# %%
with open("./exact_kernel_spectrum.npy", "r") as f:
    spectrums_exact = np.load(f)
# np.savetxt("./exact_kernel_spectrum_1024.txt", spectrums_exact, delimiter=",")

# %%
with open("./spectrum_rff_pca_sqr_with_l2_n_base_feat_1024.pkl", "r") as f:
    spectrums = cp.load(f)
with open("./spectrum_rff_pca_sqr_with_l2_n_base_feat_1024_auto_scale.pkl", "r") as f:
    spectrums_auto = cp.load(f)
# with open("./results_rff_pca_sqr_with_l2_n_base_feat_1024.pkl", "r") as f:
#     results = cp.load(f)
# np.savetxt("./fp_rff_kernel_spectrum_1024.txt", spectrums["fp_rff_error"], delimiter=",")

# %%
print spectrums.keys(), len(spectrums.keys())
print spectrums_auto.keys(), len(spectrums_auto.keys())
# Out:
# ['lp_rff_budget_128_nbit_8_seed_1', 'lp_rff_budget_256_nbit_1_seed_1', 'lp_rff_budget_256_nbit_2_seed_1', 'lp_rff_budget_32_nbit_4_seed_1', 'lp_pca_sqr_rff_budget_256_mu_1.0_seed_1', 'lp_pca_sqr_rff_budget_128_mu_30.0_seed_1', 'lp_pca_sqr_rff_budget_256_mu_20.0_seed_1', 'lp_pca_sqr_rff_budget_128_mu_10.0_seed_1', 'lp_pca_sqr_rff_budget_64_mu_3.0_seed_1', 'lp_pca_sqr_rff_budget_256_mu_2.0_seed_1', 'lp_rff_budget_64_nbit_4_seed_1', 'lp_pca_sqr_rff_budget_32_mu_10.0_seed_1', 'lp_rff_budget_64_nbit_2_seed_1', 'lp_pca_sqr_rff_budget_64_mu_30.0_seed_1', 'lp_pca_sqr_rff_budget_256_mu_5.0_seed_1', 'lp_rff_budget_128_nbit_2_seed_1', 'fp_pca_rff_error', 'lp_pca_sqr_rff_budget_32_mu_5.0_seed_1', 'lp_pca_sqr_rff_budget_128_mu_3.0_seed_1', 'fp_rff_error', 'lp_rff_budget_256_nbit_4_seed_1', 'lp_pca_sqr_rff_budget_256_mu_30.0_seed_1', 'lp_pca_sqr_rff_budget_64_mu_10.0_seed_1', 'lp_pca_sqr_rff_budget_32_mu_3.0_seed_1', 'lp_pca_sqr_rff_budget_64_mu_2.0_seed_1', 'lp_pca_sqr_rff_budget_64_mu_1.0_seed_1
# ...

# %%
# print spectrums["fp_rff_error"]
# print spectrums["lp_pca_rff_budget_128_mu_5.0"]
# print spectrums["lp_rff_budget_128_nbit_8"]

# %%
plt.figure()
plt.semilogy(spectrums["fp_rff_error"], label="fp rff", color=colors_dict["fp"])
plt.semilogy(spectrums_exact, label="exact", color=colors_dict["exact"])
plt.semilogy(spectrums["lp_rff_budget_128_nbit_8_seed_1"], label="8 bits", color=colors_dict["8"])
plt.semilogy(spectrums["lp_rff_budget_128_nbit_4_seed_1"], label="4 bits", color=colors_dict["4"])
plt.semilogy(spectrums["lp_rff_budget_128_nbit_2_seed_1"], label="2 bits", color=colors_dict["2"])
plt.semilogy(spectrums["lp_rff_budget_128_nbit_1_seed_1"], label="1 bits", color=colors_dict["1"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_128_perc_0.0_seed_1"], label="pca auto 0.0", color=colors_dict["pca"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_128_perc_0.1_seed_1"], label="pca auto 0.1", color=colors_dict["pca_2"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_128_perc_1.0_seed_1"], label="pca auto 1.0", color=colors_dict["32"])
# plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_128_perc_10.0_seed_1"], label="pca auto 10.0", color=colors_dict["16"])
plt.legend()
plt.xlim([0, 2048])
plt.ylim([1e-5, 1e3])
plt.grid()
plt.legend(framealpha=0.3, fontsize=12)
plt.ylabel("Squared singular value of rff matrix", fontsize=12)
plt.xlabel("Singular value idx ordered by value", fontsize=12)
plt.savefig("../../notes/figures/pca_sqr_rff_spectrum_base_1024_budget_128_auto_scale.pdf")
plt.show()

# %%
plt.figure()
plt.semilogy(spectrums["fp_rff_error"], label="fp rff", color=colors_dict["fp"])
plt.semilogy(spectrums_exact, label="exact", color=colors_dict["exact"])
plt.semilogy(spectrums["lp_rff_budget_256_nbit_8_seed_1"], label="8 bits", color=colors_dict["8"])
plt.semilogy(spectrums["lp_rff_budget_256_nbit_4_seed_1"], label="4 bits", color=colors_dict["4"])
plt.semilogy(spectrums["lp_rff_budget_256_nbit_2_seed_1"], label="2 bits", color=colors_dict["2"])
plt.semilogy(spectrums["lp_rff_budget_256_nbit_1_seed_1"], label="1 bits", color=colors_dict["1"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_128_perc_0.0_seed_1"], label="pca auto 0.0", color=colors_dict["pca"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_128_perc_0.1_seed_1"], label="pca auto 0.1", color=colors_dict["pca_2"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_128_perc_1.0_seed_1"], label="pca auto 1.0", color=colors_dict["32"])
plt.legend()
plt.xlim([0, 2048])
plt.ylim([1e-5, 1e3])
plt.grid()
plt.legend(framealpha=0.3, fontsize=12)
plt.ylabel("Squared singular value of rff matrix", fontsize=12)
plt.xlabel("Singular value idx ordered by value", fontsize=12)
plt.savefig("../../notes/figures/pca_sqr_rff_spectrum_base_1024_budget_256_auto_scale.pdf")
plt.show()

# %%
with open("./spectrum_rff_pca_sqr_with_l2_n_base_feat_8192.pkl", "r") as f:
    spectrums = cp.load(f)
with open("./spectrum_rff_pca_sqr_with_l2_n_base_feat_8192_auto_scale.pkl", "r") as f:
    spectrums_auto = cp.load(f)
# with open("./results_rff_pca_sqr_with_l2_n_base_feat_8192.pkl", "r") as f:
#     results = cp.load(f)

# %%
# np.savetxt("./1_bit_lp_rff_kernel_spectrum_1024.txt", spectrums["lp_rff_budget_1024_nbit_1_seed_1"], delimiter=",")
# np.savetxt("./2_bit_lp_rff_kernel_spectrum_1024.txt", spectrums["lp_rff_budget_1024_nbit_2_seed_1"], delimiter=",")
# np.savetxt("./4_bit_lp_rff_kernel_spectrum_1024.txt", spectrums["lp_rff_budget_1024_nbit_4_seed_1"], delimiter=",")
# np.savetxt("./8_bit_lp_rff_kernel_spectrum_1024.txt", spectrums["lp_rff_budget_1024_nbit_4_seed_1"], delimiter=",")

# %%
# plt.figure()
# plt.semilogy(spectrums["lp_rff_budget_1024_nbit_1_seed_1"])
# plt.semilogy(spectrums["lp_rff_budget_1024_nbit_2_seed_1"])
# plt.semilogy(spectrums["lp_rff_budget_1024_nbit_4_seed_1"])
# plt.semilogy(spectrums["lp_rff_budget_1024_nbit_8_seed_1"])
# plt.show()

# %%
print spectrums.keys(), len(spectrums.keys())
print spectrums_auto.keys(), len(spectrums_auto.keys())
# Out:
# ['lp_pca_sqr_rff_budget_1024_mu_10.0_seed_1', 'lp_rff_budget_256_nbit_1_seed_1', 'lp_rff_budget_256_nbit_2_seed_1', 'lp_rff_budget_1024_nbit_4_seed_1', 'lp_pca_sqr_rff_budget_2048_mu_20.0_seed_1', 'lp_rff_budget_1024_nbit_2_seed_1', 'lp_rff_budget_2048_nbit_8_seed_1', 'lp_pca_sqr_rff_budget_2048_mu_10.0_seed_1', 'lp_pca_sqr_rff_budget_256_mu_1.0_seed_1', 'lp_pca_sqr_rff_budget_512_mu_2.0_seed_1', 'lp_rff_budget_2048_nbit_1_seed_1', 'lp_pca_sqr_rff_budget_2048_mu_3.0_seed_1', 'lp_pca_sqr_rff_budget_256_mu_5.0_seed_1', 'lp_rff_budget_512_nbit_8_seed_1', 'lp_pca_sqr_rff_budget_1024_mu_1.0_seed_1', 'fp_pca_rff_error', 'lp_pca_sqr_rff_budget_2048_mu_2.0_seed_1', 'lp_pca_sqr_rff_budget_2048_mu_5.0_seed_1', 'fp_rff_error', 'lp_rff_budget_256_nbit_4_seed_1', 'lp_pca_sqr_rff_budget_512_mu_5.0_seed_1', 'lp_rff_budget_1024_nbit_1_seed_1', 'lp_pca_sqr_rff_budget_2048_mu_50.0_seed_1', 'lp_pca_sqr_rff_budget_256_mu_10.0_seed_1', 'lp_rff_budget_512_nbit_1_seed_1', 'lp_pca_sqr_rff_budget_2048_mu_1.0
# ...

# %%
print spectrums_exact
print spectrums["fp_rff_error"]
# Out:
# [  1.46234107e+04   3.02298603e+02   2.27614283e+02 ...,   1.24798962e-08
#    1.17846398e-08   9.89860781e-17]
# [  1.45426358e+04   3.08469761e+02   2.33630567e+02 ...,   1.91243796e-14
#    1.16731326e-14   3.92879466e-15]

# %%
plt.figure()
plt.semilogy(spectrums["fp_rff_error"], label="fp rff", color=colors_dict["fp"])
plt.semilogy(spectrums_exact, label="exact", color=colors_dict["exact"])
plt.semilogy(spectrums["lp_rff_budget_2048_nbit_8_seed_1"], label="8 bits", color=colors_dict["8"])
plt.semilogy(spectrums["lp_rff_budget_2048_nbit_4_seed_1"], label="4 bits", color=colors_dict["4"])
plt.semilogy(spectrums["lp_rff_budget_2048_nbit_2_seed_1"], label="2 bits", color=colors_dict["2"])
plt.semilogy(spectrums["lp_rff_budget_2048_nbit_1_seed_1"], label="1 bits", color=colors_dict["1"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_2048_perc_0.0_seed_1"], label="pca auto 0.0", color=colors_dict["pca"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_2048_perc_0.1_seed_1"], label="pca auto 0.1", color=colors_dict["pca_2"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_2048_perc_1.0_seed_1"], label="pca auto 1.0", color=colors_dict["32"])
plt.legend()
plt.grid()
plt.legend(framealpha=0.3, fontsize=12)
plt.ylabel("Squared singular value of rff matrix", fontsize=12)
plt.xlabel("Singular value idx ordered by value", fontsize=12)
plt.savefig("../../notes/figures/pca_sqr_rff_spectrum_base_8192_budget_2048_auto_scale.pdf")
plt.show()

# %%
plt.figure()
plt.semilogy(spectrums["fp_rff_error"], label="fp rff", color=colors_dict["fp"])
plt.semilogy(spectrums_exact, label="exact", color=colors_dict["exact"])
plt.semilogy(spectrums["lp_rff_budget_1024_nbit_8_seed_1"], label="8 bits", color=colors_dict["8"])
plt.semilogy(spectrums["lp_rff_budget_1024_nbit_4_seed_1"], label="4 bits", color=colors_dict["4"])
plt.semilogy(spectrums["lp_rff_budget_1024_nbit_2_seed_1"], label="2 bits", color=colors_dict["2"])
plt.semilogy(spectrums["lp_rff_budget_1024_nbit_1_seed_1"], label="1 bits", color=colors_dict["1"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_1024_perc_0.0_seed_1"], label="pca auto 0.0", color=colors_dict["pca"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_1024_perc_0.1_seed_1"], label="pca auto 0.1", color=colors_dict["pca_2"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_1024_perc_1.0_seed_1"], label="pca auto 1.0", color=colors_dict["32"])
plt.legend()
plt.grid()
plt.legend(framealpha=0.3, fontsize=12)
plt.ylabel("Squared singular value of rff matrix", fontsize=12)
plt.xlabel("Singular value idx ordered by value", fontsize=12)
plt.savefig("../../notes/figures/pca_sqr_rff_spectrum_base_8192_budget_1024_auto_scale.pdf")
plt.show()

# %%
plt.figure()
plt.semilogy(spectrums["fp_rff_error"], label="fp rff", color=colors_dict["fp"])
plt.semilogy(spectrums_exact, label="exact", color=colors_dict["exact"])
plt.semilogy(spectrums["lp_rff_budget_512_nbit_8_seed_1"], label="8 bits", color=colors_dict["8"])
plt.semilogy(spectrums["lp_rff_budget_512_nbit_4_seed_1"], label="4 bits", color=colors_dict["4"])
plt.semilogy(spectrums["lp_rff_budget_512_nbit_2_seed_1"], label="2 bits", color=colors_dict["2"])
plt.semilogy(spectrums["lp_rff_budget_512_nbit_1_seed_1"], label="1 bits", color=colors_dict["1"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_512_perc_0.0_seed_1"], label="pca auto 0.0", color=colors_dict["pca"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_512_perc_0.1_seed_1"], label="pca auto 0.1", color=colors_dict["pca_2"])
plt.semilogy(spectrums_auto["lp_pca_sqr_rff_budget_512_perc_1.0_seed_1"], label="pca auto 1.0", color=colors_dict["32"])
plt.grid()
plt.legend(framealpha=0.3, fontsize=12, loc="upper right")
plt.ylabel("Squared singular value of rff matrix", fontsize=12)
plt.xlabel("Singular value idx ordered by value", fontsize=12)
plt.savefig("../../notes/figures/pca_sqr_rff_spectrum_base_8192_budget_512_auto_scale.pdf")
plt.show()

# %% [markdown]
# ### below are old code

# %%
plt.figure()
plt.semilogy(spectrums["fp_rff_error"], label="fp rff")
plt.semilogy(spectrums["lp_pca_rff_budget_128_mu_5.0"], label="pca 5.0")
plt.semilogy(spectrums["lp_pca_rff_budget_128_mu_10.0"], label="pca 10.0")
plt.semilogy(spectrums["lp_rff_budget_128_nbit_8"], label="8 bits")
plt.semilogy(spectrums["lp_rff_budget_128_nbit_4"], label="4 bits")
plt.semilogy(spectrums["lp_rff_budget_128_nbit_2"], label="2 bits")
plt.semilogy(spectrums["lp_rff_budget_128_nbit_1"], label="1 bits")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### plot the kernel error

# %%
plt.figure()
for nbit in [1, 2, 4, 8]:
    val = []
    for budget in [32, 64, 128, 256, 512, 1024]:
        key = "lp_rff_budget_" + str(budget) + "_nbit_" + str(nbit)
        val.append(results[key][0] )
    plt.semilogy(val, label="lp rff " + str(nbit) + " bit")
val = []
for budget in [32, 64, 128, 256, 512, 1024]:
    val_tmp = []
    for mu in [1.0, 2.0, 3.0, 5.0, 10.0, 0.2, 0.33, 0.5]:
        key = "lp_pca_rff_budget_" + str(budget) + "_mu_" + str(mu)
        val_tmp.append(results[key][0] )
    val.append(min(val_tmp))
plt.semilogy(val, label="lp pca rff ")
plt.grid()
plt.legend()
plt.title("kernel approx error to exact kernel")
plt.show()

# %%
plt.figure()
for nbit in [1, 2, 4, 8]:
    val = []
    for budget in [32, 64, 128, 256, 512, 1024]:
        key = "lp_rff_budget_" + str(budget) + "_nbit_" + str(nbit)
        val.append(results[key][1] )
    plt.semilogy(val, label="lp rff " + str(nbit) + " bit")
val = []
for budget in [32, 64, 128, 256, 512, 1024]:
    val_tmp = []
    for mu in [1.0, 2.0, 3.0, 5.0, 10.0, 0.2, 0.33, 0.5]:
        key = "lp_pca_rff_budget_" + str(budget) + "_mu_" + str(mu)
        val_tmp.append(results[key][1] )
    val.append(min(val_tmp))
plt.semilogy(val, label="lp pca rff ")
plt.grid()
plt.legend()
plt.title("kernel approx error to fp rff")
plt.show()

# %%
plt.figure()
for nbit in [1, 2, 4, 8]:
    val = []
    for budget in [32, 64, 128, 256, 512, 1024]:
        key = "lp_rff_budget_" + str(budget) + "_nbit_" + str(nbit)
        val.append(results[key][1] )
    plt.semilogy(val, label="lp rff " + str(nbit) + " bit")
val = []
for budget in [32, 64, 128, 256, 512, 1024]:
    val_tmp = []
    for mu in [1.0, 2.0, 3.0, 5.0, 10.0, 0.2, 0.33, 0.5]:
        key = "lp_pca_rff_budget_" + str(budget) + "_mu_" + str(mu)
        val_tmp.append(results[key][1] )
    val.append(min(val_tmp))
plt.semilogy(val, label="lp pca rff ")
plt.grid()
plt.legend()
plt.title("kernel approx error to fp rff")
plt.show()

# %%
plt.figure()
for nbit in [1, 2, 4, 8]:
    val = []
    for budget in [32, 64, 128, 256, 512, 1024]:
        key = "lp_rff_budget_" + str(budget) + "_nbit_" + str(nbit)
        val.append(results[key][3] )
    plt.semilogy(val, label="lp rff " + str(nbit) + " bit")
val = []
for budget in [32, 64, 128, 256, 512, 1024]:
    val_tmp = []
    for mu in [1.0, 2.0, 3.0, 5.0, 10.0, 0.2, 0.33, 0.5]:
        key = "lp_pca_rff_budget_" + str(budget) + "_mu_" + str(mu)
        val_tmp.append(results[key][3] )
    val.append(min(val_tmp))
plt.semilogy(val, label="lp pca rff ")
plt.grid()
plt.legend()
plt.title("test l2 loss")
plt.show()
