# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import csv
import os, sys
from latexifypaper import *
from csv_plot import *
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
from matplotlib import gridspec

# %%
figsize=[3.1, 2.5]
label_font=13
legend_font = 11

# %% [markdown]
# # census

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/census_MSE_vs_n_memory.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 12)

# %%
# def plot_figure_with_error_bar(names, data, color_list):
#     '''
#     each column of data is a line
#     the name follows the pattern like ['fp Nystrom-x', 'fp Nystrom-y', 'fp Nystrom-y_std', 'fp RFF-x', 'fp RFF-y', 'fp RFF-y_std']
#     '''
#     marker_list = ['o', 'v', '^', 's', 'h', 'd', '+']
#     for i in range(data.shape[1] // 3):
#         idx = i * 3
#         label = names[idx].split("|")[0]
#         print "label ", names[idx], label
#         x = data[:, idx]
#         average_y = data[:, idx + 1]
#         std_y = data[:, idx + 2]
# #         print x, average_y, std_y
#         if "FP" in label:
#             print "FP mode plot"
#             plt.errorbar(x, average_y, yerr=std_y, label=label, marker=marker_list[i], markeredgecolor=color_list[i % len(color_list)], fmt=":", linewidth=1, capsize=3.5, capthick=1, color=color_list[i % len(color_list)])
#         else:
#             print "LP mode plot"
#             plt.errorbar(x, average_y, yerr=std_y, label=label, marker=marker_list[i], markeredgecolor=color_list[i % len(color_list)], fmt="-", linewidth=1, capsize=3.5, capthick=1, color=color_list[i % len(color_list)])

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([8e7, 1.5e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/census_MSE_vs_n_memory.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# /Users/Jian/anaconda/lib/python2.7/site-packages/matplotlib/scale.py:101: RuntimeWarning: invalid value encountered in less_equal
#   a[a <= 0.0] = 1e-300

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/census_MSE_vs_n_feat.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 12)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([8e7, 1.5e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census")
leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/census_MSE_vs_n_feat.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# # yearpred

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/yearpred_MSE_vs_n_memory.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 12)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([8e7, None])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("YearPred", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/yearpred_MSE_vs_n_memory.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/yearpred_MSE_vs_n_feat.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 12)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([8e7, 1.5e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("YearPred", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/yearpred_MSE_vs_n_feat.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# # covtype

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/covtype_error_vs_n_memory.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 12)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.ylim([None, 0.25])
# plt.ylim([8e7, None])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/covtype_error_vs_n_memory.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/covtype_error_vs_n_feat.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 12)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.ylim([None, 0.25])
# plt.ylim([8e7, 1.5e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/covtype_error_vs_n_feat.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# # TIMIT

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/timit_error_vs_n_memory.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 12)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.xlim([1e7, 2e10])
plt.ylim([None, 0.39])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("TIMIT", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/timit_error_vs_n_memory.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/timit_error_vs_n_feat.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 12)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.ylim([None, 0.42])
# plt.ylim([8e7, 1.5e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("TIMIT", fontsize=label_font)
leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/timit_error_vs_n_feat.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# # all lines

# %% [markdown]
# # census

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/census_MSE_vs_n_memory_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
print data[:, 1]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 18)
# [ 89097420.13659446  87080557.43432839  85801194.70463473
#   85496761.98864914  85428864.49040301                nan
#                 nan                nan                nan]

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([8.2e7, 1e8])
plt.xlim([1e6, 2e10])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/census_MSE_vs_n_memory_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/census_MSE_vs_n_feat_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 18)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([8e7, 1.5e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.5, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/census_MSE_vs_n_feat_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# # yearpred

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/yearpred_MSE_vs_n_memory_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 18)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=[3.3, 2.6])
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.ylim([None, 88])
plt.xlim([1e6, 1e10])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("YearPred", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/yearpred_MSE_vs_n_memory_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/yearpred_MSE_vs_n_feat_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 18)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([8e7, 1.5e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("YearPred", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/yearpred_MSE_vs_n_feat_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# # covtype

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/covtype_error_vs_n_memory_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 18)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.xlim([1e6, 2e10])
plt.ylim([None, 0.3])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.5, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/covtype_error_vs_n_memory_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/covtype_error_vs_n_feat_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 18)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([8e7, 1.5e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.3, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/covtype_error_vs_n_feat_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# # TIMIT

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/timit_error_vs_n_memory_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 18)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.xlim([1e7, 2e10])
plt.ylim([0.31, 0.38])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("TIMIT", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/timit_error_vs_n_memory_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/timit_error_vs_n_feat_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 18)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.ylim([0.31, 0.38])
# plt.ylim([8e7, 1.5e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("TIMIT", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/timit_error_vs_n_feat_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# # plot everything with lightweighted plot

# %%
# def plot_figure_without_error_bar(names, data, color_list):
#     '''
#     each column of data is a line
#     the name follows the pattern like ['fp Nystrom-x', 'fp Nystrom-y', 'fp Nystrom-y_std', 'fp RFF-x', 'fp RFF-y', 'fp RFF-y_std']
#     '''
#     marker_list = ['v', 'd', 'o', 's', '+', '^', 'h', '*', 'x']
#     for i in range(data.shape[1] // 3):
#         idx = i * 3
#         label = names[idx].split("|")[0]
#         print "label ", names[idx], label
#         x = data[:, idx]
#         average_y = data[:, idx + 1]
#         std_y = data[:, idx + 2]
# #         print x, average_y, std_y
#         if "FP" in label:
#             print "FP mode plot", marker_list[i]
#             plt.plot(x, average_y, "-", label=label, marker=marker_list[i], markeredgecolor=color_list[i % len(color_list)], markerfacecolor="none", markersize=6, markeredgewidth=1, linewidth=1, color=color_list[i % len(color_list)])
# #             plt.errorbar(x, average_y, yerr=std_y, label=label, marker=marker_list[i], markeredgecolor=color_list[i % len(color_list)], markerfacecolor="none", markersize=5, markeredgewidth=1, fmt="-", linewidth=1, capsize=5, capthick=1, color=color_list[i % len(color_list)])
#         else:
#             print "LP mode plot", marker_list[i]
#             plt.plot(x, average_y, "--", label=label, marker=marker_list[i], markeredgecolor=color_list[i % len(color_list)], markerfacecolor="none", markersize=6, markeredgewidth=1, linewidth=1, color=color_list[i % len(color_list)])
# #             plt.errorbar(x, average_y, yerr=std_y, label=label, marker=marker_list[i], markeredgecolor=color_list[i % len(color_list)], markerfacecolor="none", markersize=5, markeredgewidth=1, fmt="--", linewidth=1, capsize=5, capthick=1, color=color_list[i % len(color_list)])

# %%
legend_font = 10

# %% [markdown]
# # census

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/census_MSE_vs_n_memory_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
print data[:, 1]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 24)
# [ 89097420.13659446  87080557.43432839  85801194.70463473
#   85496761.98864914  85428864.49040301                nan
#                 nan                nan                nan]

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data[:,], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([8.5e7, 1e8])
plt.xlim([1e6, 2e10])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/census_MSE_vs_n_memory_every_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/census_MSE_vs_n_feat_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 24)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data[:,], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([8e7, 1.2e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/census_MSE_vs_n_feat_every_line.pdf", bbox_extra_artists=(leg,), bbox_inches='tight')
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# # yearpred

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/yearpred_MSE_vs_n_memory_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 24)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=[3.3, 2.6])
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.ylim([None, 88])
plt.xlim([1e6, 1e10])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("YearPred", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/yearpred_MSE_vs_n_memory_every_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/yearpred_MSE_vs_n_feat_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 24)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([8e7, 1.5e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("YearPred", fontsize=label_font)
leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/yearpred_MSE_vs_n_feat_every_line.pdf", bbox_extra_artists=(leg,), bbox_inches='tight')
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# # covtype

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/covtype_error_vs_n_memory_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 24)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.xlim([1e6, 2e10])
plt.ylim([None, 0.25])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/covtype_error_vs_n_memory_every_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/covtype_error_vs_n_feat_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 24)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.ylim([None, 0.25])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/covtype_error_vs_n_feat_every_line.pdf", bbox_extra_artists=(leg,), bbox_inches='tight')
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# # TIMIT

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/timit_error_vs_n_memory_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 24)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.xlim([1e7, 2e10])
plt.ylim([0.31, 0.38])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("TIMIT", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/timit_error_vs_n_memory_every_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/timit_error_vs_n_feat_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7', '8']
# (9, 24)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.ylim([0.31, 0.38])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("\# of features", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("TIMIT", fontsize=label_font)
leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/timit_error_vs_n_feat_every_line.pdf", bbox_extra_artists=(leg,), bbox_inches='tight')
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *
