# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import csv
import os, sys
from latexifypaper import *
from csv_plot import *
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
from matplotlib import gridspec

# %%
figsize=[3.1, 2.5]

# %%
label_font=13
legend_font = 11

# %% [markdown]
# # plot census

# %% [markdown]
# ### MSE vs memory

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_mem.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2.5e7, 1e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_mem.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# /Users/Jian/anaconda/lib/python2.7/site-packages/matplotlib/scale.py:101: RuntimeWarning: invalid value encountered in less_equal
#   a[a <= 0.0] = 1e-300

# %% [markdown]
# ### relative spectral vs memory

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_delta_vs_mem.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([None, 1e3])
plt.xlim([None, 2e10])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Rel. spectral dist.", fontsize=label_font)
plt.title("Census", fontsize=label_font)
# leg=plt.legend(framealpha=0.8, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_delta_vs_mem.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# ### MSE vs delta

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_delta.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7']
# (8, 12)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2.4e7, 1.1e8])
plt.xlim([None, 4e2])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Rel. spectral dist.", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
# leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_delta.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# ### MSE vs f norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_f_norm.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2.5e7, 1.5e8])
plt.xlim([1e-4, None])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Frobenius norm", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_f_norm.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# ### MSE vs s norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_s_norm.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2e7, 1e8])
plt.xlim([None, 1e2])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Spectral norm", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_s_norm.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# # Plot covtype

# %% [markdown]
# ### error vs mem

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_mem.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([2e7, 1e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Rel. spectral dist.", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper right")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_mem.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# ### delta vs mem

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_delta_vs_mem.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([1e2, None])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.ylabel("Rel. spectral dist.", fontsize=label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="lower right")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_delta_vs_mem.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# ### error vs delta

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_delta.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([2e7, 1e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Rel. spectral dist.", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_delta.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# ### error vs f norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_f_norm.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([2e7, 1e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Frobenius norm", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_f_norm.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# ### error vs s norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_s_norm.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([2e7, 1e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Spectral norm", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_s_norm.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot

# %% [markdown]
# # plot all lines

# %% [markdown]
# # plot census

# %% [markdown]
# ### MSE vs memory

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_mem_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7']
# (8, 18)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2.5e7, 1e8])
plt.xlim([1e6, 2e10])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.5, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_mem_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# ### relative spectral vs memory

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_delta_vs_mem_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([None, 1e5])
plt.xlim([1e6, 1e9])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Rel. spectral dist.", fontsize=label_font)
plt.title("Census", fontsize=label_font)
# leg=plt.legend(framealpha=0.3, fontsize=legend_font)
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_delta_vs_mem_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# ### MSE vs delta

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_delta_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data, colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2.5e7, 2e8])
plt.xlim([3e-1, 3e3])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Rel. spectral dist.", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
# leg=plt.legend(framealpha=0.3, fontsize=legend_font, loc="upper right")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_delta_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# ### MSE vs f norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_f_norm_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data, colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2.5e7, 1e8])
plt.xlim([1e-4, 1e4])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Frobenius norm", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.3, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_f_norm_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# ### MSE vs s norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_s_norm_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data, colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2e7, 1e8])
plt.xlim([None, 1e2])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Spectral norm", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
# leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_s_norm_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# # Plot covtype

# %% [markdown]
# ### error vs mem

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_mem_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.ylim([None, 0.5])
plt.xlim([None, 1e11])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Rel. spectral dist.", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
leg=plt.legend(framealpha=0.3, fontsize=legend_font, loc="upper right")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_mem_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# ### delta vs mem

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_delta_vs_mem_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data, colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
# plt.ylim([2e7, 1e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.ylabel("Rel. spectral dist.", fontsize=label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="lower right")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_delta_vs_mem_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# ### error vs delta

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_delta_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data, colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([2e7, 1e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Rel. spectral dist.", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_delta_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# ### error vs f norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_f_norm_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data, colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([2e7, 1e8])
plt.xlim([None, 3e6])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Frobenius norm", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.3, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_f_norm_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# ### error vs s norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_s_norm_all_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data, colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.xlim([3e0, 3e2])
plt.ylim([0.15, None])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Spectral norm", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_s_norm_all_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  FP-RFF|x FP-RFF
# FP mode plot
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot

# %% [markdown]
# # plot lines for every precision

# %% [markdown]
# # plot census

# %%
legend_font=10

# %% [markdown]
# ### MSE vs memory

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_mem_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
print data.shape
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7']
# (8, 24)

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data[:], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2.5e7, 1e8])
plt.xlim([1e6, 2e10])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_mem_every_line.pdf", bbox_extra_artists=(leg,), bbox_inches='tight')
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# ### relative spectral vs memory

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_delta_vs_mem_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data[:,], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([None, 1e5])
plt.xlim([1e6, 1e9])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Rel. spectral dist.", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_delta_vs_mem_every_line.pdf", bbox_extra_artists=(leg,), bbox_inches='tight')
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# ### MSE vs delta

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_delta_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data, colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2.5e7, 2e8])
plt.xlim([3e-1, 3e3])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Rel. spectral dist.", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_delta_every_line.pdf", bbox_extra_artists=(leg,), bbox_inches='tight')
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# ### MSE vs f norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_f_norm_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data, colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2.5e7, 1e8])
plt.xlim([1e-3, 1e4])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Frobenius norm", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_f_norm_every_line.pdf", bbox_extra_artists=(leg,), bbox_inches='tight')
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# ### MSE vs s norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/regression_l2_vs_s_norm_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6', '7']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data, colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2e7, 1e8])
plt.xlim([None, 1e2])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Spectral norm", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.8, ncol=1, fontsize=legend_font, bbox_to_anchor=(1.6, 1.1))
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/regression_l2_vs_s_norm_every_line.pdf", bbox_extra_artists=(leg,), bbox_inches='tight')
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# # Plot covtype

# %% [markdown]
# ### error vs mem

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_mem_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data[:,], colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.ylim([None, 0.45])
plt.xlim([None, 1.6e10])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.3, fontsize=legend_font, loc="upper right")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_mem_every_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# ### delta vs mem

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_delta_vs_mem_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data, colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
# plt.ylim([2e7, 1e8])
plt.xlim([None, 1.6e10])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.ylabel("Rel. spectral dist.", fontsize=label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="lower right")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_delta_vs_mem_every_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# ### error vs delta

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_delta_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data, colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([2e7, 1e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Rel. spectral dist.", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_delta_every_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# ### error vs f norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_f_norm_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data, colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
# plt.ylim([2e7, 1e8])
plt.xlim([None, 3e6])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Frobenius norm", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.3, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_f_norm_every_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *

# %% [markdown]
# ### error vs s norm

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/classification_acc_vs_s_norm_every_line.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'FP-RFF|x', 'FP-RFF|y', 'FP-RFF|y_std', 'Cir. FP-RFF|x', 'Cir. FP-RFF|y', 'Cir. FP-RFF|y_std', 'LP-RFF 16|x', 'LP-RFF 16|y', 'LP-RFF 16|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-RFF 4|x', 'LP-RFF 4|y', 'LP-RFF 4|y_std', 'LP-RFF 2|x', 'LP-RFF 2|y', 'LP-RFF 2|y_std', 'LP-RFF 1|x', 'LP-RFF 1|y', 'LP-RFF 1|y_std']
# ['1', '2', '3', '4', '5', '6']

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=figsize)
ax = plt.subplot(111)
plot_figure_without_error_bar(groups, data, colors)
plt.grid()
# plt.yscale("log")
plt.xscale("log")
plt.xlim([3e0, 3e2])
plt.ylim([0.15, None])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Spectral norm", fontsize=label_font)
plt.ylabel("Heldout error", fontsize=label_font)
plt.title("CovType", fontsize=label_font)
# leg=plt.legend(framealpha=0.5, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/classification_acc_vs_s_norm_every_line.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot v
# label  FP-RFF|x FP-RFF
# FP mode plot d
# label  Cir. FP-RFF|x Cir. FP-RFF
# FP mode plot o
# label  LP-RFF 16|x LP-RFF 16
# LP mode plot s
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot +
# label  LP-RFF 4|x LP-RFF 4
# LP mode plot ^
# label  LP-RFF 2|x LP-RFF 2
# LP mode plot h
# label  LP-RFF 1|x LP-RFF 1
# LP mode plot *
