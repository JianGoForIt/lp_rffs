# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import csv
import os, sys
from latexifypaper import *
from csv_plot import *
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
from matplotlib import gridspec

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/lp_nystrom_mse_vs_mem.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-Nystrom 8|x', 'LP-Nystrom 8|y', 'LP-Nystrom 8|y_std', 'LP-Nystrom 16|x', 'LP-Nystrom 16|y', 'LP-Nystrom 16|y_std']
# ['1', '2', '3', '4', '5']

# %%
label_font=12
legend_font = 10

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=[3.3, 2.6])
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2.5e7, 3e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.3, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/lp_nystrom_mse_vs_mem.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-Nystrom 8|x LP-Nystrom 8
# LP mode plot
# label  LP-Nystrom 16|x LP-Nystrom 16
# LP mode plot
# /Users/Jian/anaconda/lib/python2.7/site-packages/matplotlib/scale.py:101: RuntimeWarning: invalid value encountered in less_equal
#   a[a <= 0.0] = 1e-300

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/lp_nystrom_delta_vs_mem.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'LP-Nystrom 8|x', 'LP-Nystrom 8|y', 'LP-Nystrom 8|y_std', 'LP-Nystrom 16|x', 'LP-Nystrom 16|y', 'LP-Nystrom 16|y_std']
# ['1', '2', '3', '4', '5']

# %%
label_font=12
legend_font = 10

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=[3.3, 2.6])
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
# plt.ylim([2.5e7, 3e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Rel. spectral dist.", fontsize=label_font)
plt.title("Census", fontsize=label_font)
# leg=plt.legend(framealpha=0.3, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/lp_nystrom_delta_vs_mem.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  LP-Nystrom 8|x LP-Nystrom 8
# LP mode plot
# label  LP-Nystrom 16|x LP-Nystrom 16
# LP mode plot

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/lp_ensemble_nystrom_mse_vs_mem.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'Ens. LP-Nystrom 8|x', 'Ens. LP-Nystrom 8|y', 'Ens. LP-Nystrom 8|y_std', 'Ens. LP-Nystrom 16|x', 'Ens. LP-Nystrom 16|y', 'Ens. LP-Nystrom 16|y_std', 'Ens. FP-Nystrom|x', 'Ens. FP-Nystrom|y', 'Ens. FP-Nystrom|y_std']
# ['1', '2', '3', '4', '5']

# %%
label_font=12
legend_font = 10

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=[3.3, 2.6])
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
plt.ylim([2.5e7, 3e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Heldout MSE", fontsize=label_font)
plt.title("Census", fontsize=label_font)
leg=plt.legend(framealpha=0.3, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/lp_ensemble_nystrom_mse_vs_mem.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  Ens. LP-Nystrom 8|x Ens. LP-Nystrom 8
# LP mode plot
# label  Ens. LP-Nystrom 16|x Ens. LP-Nystrom 16
# LP mode plot

# %%
csv_file_name = "/Users/Jian/Data/research/lp_kernel/lp_kernel/paper/data_for_plot/lp_ensemble_nystrom_delta_vs_mem.csv"

# %%
groups, names, data = csv_to_table(csv_file_name)
names = names[1:]
print groups
print names
# print data.shape
# print data[:, 0], data[:, 1], data[:, 2]
# Out:
# ['FP-Nystrom|x', 'FP-Nystrom|y', 'FP-Nystrom|y_std', 'LP-RFF 8|x', 'LP-RFF 8|y', 'LP-RFF 8|y_std', 'Ens. LP-Nystrom 8|x', 'Ens. LP-Nystrom 8|y', 'Ens. LP-Nystrom 8|y_std', 'Ens. LP-Nystrom 16|x', 'Ens. LP-Nystrom 16|y', 'Ens. LP-Nystrom 16|y_std', 'Ens. FP-Nystrom|x', 'Ens. FP-Nystrom|y', 'Ens. FP-Nystrom|y_std']
# ['1', '2', '3', '4', '5']

# %%
label_font=12
legend_font = 10

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
latexify(columns=1)
plt.figure()
fig = plt.figure(figsize=[3.3, 2.6])
ax = plt.subplot(111)
plot_figure_with_error_bar(groups, data[:, :12], colors)
plt.grid()
plt.yscale("log")
plt.xscale("log")
# plt.ylim([2.5e7, 3e8])
# set_fig_xtick(np.arange(0, 60001, 10000) / float(250), [str(int(num/1000)) + "k" for num in range(0, 60001, 10000)], 18),
# set_fig_ytick([2.5e7, 1e8], [r"$2.5e^7$", "$1e^8$"], label_font)
plt.xlabel("Memory (bits)", fontsize=label_font)
plt.ylabel("Rel. spectral dist.", fontsize=label_font)
plt.title("Census", fontsize=label_font)
# leg=plt.legend(framealpha=0.3, fontsize=legend_font, loc="upper left")
leg.get_frame().set_linewidth(0.0)
format_axes(ax)
plt.tight_layout()
plt.savefig("../figures/lp_ensemble_nystrom_delta_vs_mem.pdf")
plt.show()
# Out:
# label  FP-Nystrom|x FP-Nystrom
# FP mode plot
# label  LP-RFF 8|x LP-RFF 8
# LP mode plot
# label  Ens. LP-Nystrom 8|x Ens. LP-Nystrom 8
# LP mode plot
# label  Ens. LP-Nystrom 16|x Ens. LP-Nystrom 16
# LP mode plot
